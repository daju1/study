# %%
C = 90 * 10^(-12) # pikaFarad
R = 2690 # Omh
L = 45 * 10^(-3) # mGenry

# %%
f = 1/(2*pi*sqrt(L * C))
f.n()
# Out:
# 79084.7270463530

# %%
izmerenija_air = [
    [2.47, 33.6, [0.182, ]],
    [2.52, 33.2, [0.192, ]],
    [2.57, 33.2, [0.216, ]],
    [3.00, 33.2, [0.200, ]],
    [4.02, 33.2, [0.260, 0.272, 0.254, 0.256, ]],
    [4.98, 33.2, [0.316, 0.316, 0.304, 0.308, ]],
    [5.96, 33.2, [0.376, 0.364, 0.376, 0.380, 0.376, ]],
    [7.02, 32.8, [0.408, 0.420, 0.408, ]],
    [8.01, 33.2, [0.468, 0.468, 0.460, 0.476, ]],
    [8.99, 33.2, [0.536, 0.524, 0.520, ]],
    [9.96, 33.2, [0.548, 0.564, 0.568, 0.564, ]],
    [11.035, 33.2, [0.624, 0.616, 0.616, 0.624, ]],
    [12.02, 33.2, [0.680, 0.688, 0.696, 0.688, 0.672, ]],
    [13.02, 33.2, [0.744, 0.744, 0.744, ]],
    [13.97, 33.2, [0.800, 0.808, 0.816, ]],
    [15.06, 33.8, [0.864, 0.872, 0.872, ]],
    [15.53, 34, [0.896, 0.896, 0.912, 0.904, ]],
    [16.08, 33.2, [0.960, 0.944, 0.944, ]],
    [17.01, 33.6, [1.1, 1.08, 1.1, ]],
    [17.48, 34.4, [1.12, 1.14, 1.14, 1.12, ]],
    [17.99, 33.8, [1.18, 1.2, 1.16, 1.2, 1.2, 1.2, ]],
    [18.52, 33.2, [1.24, 1.26, 1.26, 1.26, ]],
    [19.08, 33.2, [1.34, 1.36, 1.34, 1.34, 1.34, ]],
    [19.23, 33.6, [1.4, 1.36, 1.36, 1.38, 1.4, 1.4, ]],
    [19.53, 34, [1.46, 1.44, 1.48, 1.48, 1.48, 1.46, 1.46, 1.48,]],
    [19.76, 33.6, [1.52, 1.52, 1.52, 1.52, 1.52, 1.52, 1.5, 1.52, 1.52, 1.52, 1.54, ]],
    [20.00, 34.4, [1.58, 1.58, 1.58, 1.6, 1.56, 1.58, 1.6, 1.62, 1.58, 1.58, ]],
    [20.19, 33.6, [1.68, 1.72, 1.68, 1.7, 1.68, 1.68, 1.7, 1.68, 1.68, 1.68, 1.68, 1.7, 1.7, ]],
    [20.53, 33.6, [1.88, 1.88, 1.9, 1.9, 1.9, 1.88, 1.88, 1.86, 1.9, 1.86, 1.86, 1.86, 1.86, 1.88, 1.86, ]],
    [20.8, 33.6, [2.04, 2, 2.06, 2.06, 2.04, 2.02, 2.04, 2.04, 2.02, 2, 2.02, 2.06, 2.04, 2.04, ]],
    [21.01, 32.8, [2.2, 2.16, 2.16, 2.16, 2.2, ]],
    [21.19, 32.8, [2.26, 2.22, 2.24, 2.22, 2.24, 2.24, 2.24, 2.26, 2.24, 2.24, ]],
    [21.37, 32.8, [2.14, 2.16, 2.16, 2.14, 2.18, 2.16, 2.16, 2.16, 2.16, 2.16, ]],
    [21.44, 33.2, [2.08, 2.08, 2.08, 2.04, 2.08, 2.06, 2.06, 2.06, ]],
    [21.51, 33.2, [1.9, 1.88, 1.88, 1.84, 1.9, 1.88, 1.86, 1.88, 1.88, 1.88, 1.88, 1.88, 1.9, ]],
    [21.59, 32.8, [1.7, 1.7, 1.7, 1.7, 1.7, 1.72, 1.7, 1.72, 1.72, 1.74, 1.72, ]],
    [21.74, 32.8, [1.34, 1.36, 1.36, 1.34, 1.34, 1.32, 1.38, 1.36, ]],
    [21.82, 33.2, [1.18, 1.18, 1.2, 1.18, 1.2, 1.2, 1.18, 1.18, 1.2, ]],
    [21.89, 32.8, [1, 1, 0.980, 0.980, 1, ]],
    [22.01, 33.2, [0.880, 0.880, 0.880, 0.880, 0.880, 0.900, 0.900, 0.880, ]],
    [22.05, 33.6, [0.780, 0.820, 0.820, 0.800, 0.800, 0.820, ]],
    [22.12, 33.6, [0.700, 0.680, 0.680, 0.680, 0.700, 0.700, 0.700, ]],
    [22.22, 33.6, [0.544, 0.568, 0.544, 0.552, 0.560, 0.560, 0.552, ]],
    [22.28, 33.6, [0.504, 0.520, 0.504, 0.512, 0.512, 0.512, 0.504, ]],
    [22.32, 33.2, [0.512, 0.520, 0.520, 0.528, 0.512, ]],
    
    [18.09, 32.8, [1.14, 1.16, 1.18, ]],
    [[18.74, 18.71, 18.78], [32.4,32.4,32], [1.26, ]],
    [[19.19, 19.20, 19.19], [32.4, 32.4, 32], [1.32, 1.32, 1.34]],
    [[19.62, 19.58, 19.61], [32.4], [1.42, 1.42, 1.38]],
    #[[20.03, 20.03, 20.05, ], [32, 32.4, 32], [1.88, 1.9, 1.88]]
    [[20.78, 20.64, 20.71, ], [32, 32.4, 32], [1.88, 1.9, 1.88]],
    [[21.15, 21.11, 21.11], 32, [2.14, 2.14, 2.12, 2.16, ]],
    [[21.15, 21.15, 21.17], [32, 32, 32.4], [2.14, 2.16, 2.14]],
    [[21.65, 21.66, 21.66], [32, ], [1.54, 1.56, 1.54, ]],
    [[22.10, 22.10, 22.08, ], [32, ], [0.720, 0.740, 0.720]],
    [[22.50, 22.60, ], [32, ], [0.500, 0.480, 0.480, 0.480, ]],

    [[23.00, 22.98, 23.00], [32, 32.4, 32], [0.540, 0.560, 0.520, 0.540]],
    [[23.50, 23.43, 23.47], [32.4, 32, 32], [0.680, 0.680, 0.660, ] ],
    [[23.92, 23.99, 23.97, 24.02, 24.02, 24.02, 24.02, 24.06, 23.99], [32, ], [0.740, 0.740, 0.760, ]],
    [[24.41, 24.44, 24.46, ], 32, [0.860, 0.840, 0.840]],
    [[25.00, 25.05, 25.00], [32, ], [0.880, 0.900, 0.880, ]],
    
    [[30.19, 30.12, 30.16], [31.6, 32, 32], [1.24, 1.22, 1.2, 1.24, ]],
    [[35.16, 35.26, 35.21], [31.6, 31.2, 31.2], [1.44, 1.42, 1.48, ]],
    [[40.06, 40.13, 40.13], [31.2, 31.2, 31.2], [1.64, 1.62, 1.6, ]],
    [[45.29, 45.54, 45.29], [31.2, ], [1.8, 1.78, 1.78]],
    [[50.40, 50.51, 50.40], [30.8, 30.4, 30.4], [1.94, 1.96, 1.98, ]],
    
    [[55.31, 55.56, 55.31], [30.4, ], [2.14, 2.14, 2.14, ]],
    [[60.68, 60.83, 60.68],[30.4], [2.32, 2.3, 2.28, 2.32, ]],
    [[71.02, 70.82, 70.82], [30.4, 30.4, 30], [2.6, 2.58, 2.6, 2.6, ]],
    [[81.43, 81.7], [29.6, 29.6], [2.9, 2.88, 2.84, 2.92, ]],
    
    [[102.46, 102.04], [29.6], [3.4, 3.4, 3.48, ]],
    [[123.15,123.15,123.55,], [29.6, ], [4.08, 4, 4, ]],
    [[143.68, 142.86, 143.68, 143.68], [29.6, ], [4.56, ]],
    [[166.67, ], [29.6, 30, 30], [5.04, ]],
    [[187.97, ], [30.4, ], [5.52]],
    [[210.08, ], [30.8, ], [6, 6, 5.92]],
    [[223.21, 221.24, 223.21], [31.6, 31.6, 31.2], [6.24, ]],
    [[231.48, 229.36, 231.48, 231.48, 231.48, 231.48], [31.6, ], [6.4, ]],
    [[235.85, ], [31.6], [6.48, ]],
    [[233.64, 235.85, 233.64], [31.6], [6.48]],
    [[233.64, 233.64, 231.48, ], [31.6], [6.4, 6.4, 6.4, 6.48, 6.4]]
]

# %%
f_U_air = []

# %%
import numpy as np
for f, U_generator, vU_rezistor in izmerenija_air:
    f_U_air += [(np.mean(f), np.mean(vU_rezistor)/np.mean(U_generator))]
    #print(f, U_generator, np.mean(vU_rezistor))

# %%
list_plot(f_U_air, color="green")
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
izmerenija_water = [
    [0.19873, 31.2, [24, 24.4, 24.4, ]],
    [[0.24752, 0.24802], 31.2, [24.4, 24, ]],
    [0.29976, 31.2, [24, 24, ]],
    [0.34819, 31.2, [24.4, 24, ]],
    [0.39809, 31.2, [24, 24, ]],
    [[0.44964, 0.44803], 31.2, [24, 24, ]],
    [0.49801, 31.2, [24, 24, ]],
    [0.59809, 31.2, [24, 24, ]],
    [0.80128, 31.2, [24, 24, ]],
    [1.00, 30.8, [24, ]],
    [1.19, 31.2, [24, ]],
    [1.49, 31.2, [24, ]],
    [1.74, 31.2, [24.4, ]],
    [1.99, 31.2, [24, ]],
    [2.18, 31.2, [24, ]],
    [1.81, 32, [24.8]],
    [1.98, 32, [24.8, ]],
    [2.46, 32, [24.8, ]],
    [3.47, 32, [24.8, ]],
    [3.965, 32, [24.4, ]],
    [4.47, 32.2, [24, 24, 24, 24.4, ]],
    [4.98, 32, [24, ]],
    [5.46, 32, [23.6, 24, ]],
    [5.56, 32, [23.6, 24, 24, 23.6]],
    [5.66, 32, [23.6, 23.6, 23.6, 23.6, 23.6, 24, ]],
    [5.76, 32.4, [23.6, ]],
    [5.87, 32.2, [23.6, 23.2, 23.2, 23.2, 23.2, 23.6, 23.2, ]],
    [5.95, 32, [23.2, 23.2, 23.2, 24, 24, 24]],
    [6.13, 32.4, [24, 23.6, 24, ]],
    [6.33, 32.2, [24, ]],
    [6.51, 32.4, [24, 23.6, 24]],
    [6.72, 32.4, [23.6, 24, ]],
    [6.94, [32, 32.4, ], [23.2, ]],
    [7.53, 32.4, [22.8]],
    [[7.96, 7.91], 32.8, [21.6, ]],
    [8.17, 32, [21.6, ]],
    [8.39, 32, [21.6, ]],
    [8.56, 32.4, [21.2, 21.2, 21.2, 21.6, 21.2, ]],
    [8.78, 32.8, [20.8, 20.8, 21.2, 20.8, 20.8, ]],
    [8.93, [32.8, 32.4], [20.8, ]],
    [9.19, 32.8, [20.8, ]],
    [9.33, 32.4, [20.8, 20.4, 20, 20.4]],
    [9.54, 32.4, [19.6, ]],
    [9.92, 32.8, [18.8, 18.8, 18.8, 19.6, 19.6, ]],
    [10.87, [32.4,32.2], [17.6, 18, 17.6, 17.6]],
    [11.90, 33.2, [16.4, 16.4, ]],
    [12.89, 33.2, [15.2]],
    [13.74, 33.2, [13.6, 13.6, 13.2, 13.2, 13.4, ]],
    [14.88, 33.2, [11.4, ]],
    [15.92, 33.2, [9.8, ]],
    [16.78, 33.2, [8.2, ]],
    [16.84, 33.2, [8.2, ]],
    [17.92, 33.6, [6.56, ]],
    #[[18.87, 18.87, 18.80,], [33.6,33.6, 34], []],
    [[19.90, 19.94,], [33.6,33.2,], [3.52, 3.52, 3.56, 3.56]],
    [[21.01, 20.97, 20.97, 20.94, 20.97], [34, 33.6, 33.6, 33.6, 33.6], [2.2, ] ],
    [[21.78, 21.82], 33.2, [1.12]],
    [22.28, 33.2, [0.8, 0.840, 0.840, 0.8]],
    [22.01, 33.2, [0.920, ]],
    [[18.05, 18.08, 18.02], [32.4, 32, 32.4], [6.16, 6.12, 6.12, 6.12]],
    [18.27, 32.8, [5.84, 5.88, 5.84]],
    [[18.68, 18.73], 32.4, [5.16, ]],
    [[19.13, 19.1], 32.4, [4.6, ]],
    [19.55, 32.4, [4]],
    [20.05, 32.4, [3.28, 3.24, 3.28, ]],
    [20.56, 32, [2.56, 2.6, 2.6, 2.56, 2.56, 2.56, ]],
    [21.10, 32, [1.88, 1.88, 1.88, 1.92, 1.9, 1.9, ]],
    [21.59, 32, [1.22, 1.2, 1.22]],
    [22.14, 32, [0.752, 0.760, 0.748]],
    [[22.48, 22.48, 22.46,], 32, [0.616, 0.624, 0.616, 0.616, 0.616, ]],
    [22.44, 32.2, [0.616, 0.620]],
    [22.89, 32, [0.880, 0.872]],
    [23.41, 31.8, [1.32]],
    [24.08, 31.8, [2.02, 2.06, 2.06, ]],
    [[24.44,24.49], [32,31.8], [2.54]],
    [[24.95, 24.9], 31.8, [3.02, 3.02, 3]],
    # [[25.54, 25.56, 25.48], [32, 31.8, 31.8], []],
    [26.04, 31.8, [4.1]],
    [27.14, 31.8, [5.12, 5.12, 5.04, ]],
    [[28.34, 28.25], 31.8, [6.16]],
    [[29.07, 29.1], [31.8,31.6], [6.88]],
    [[30.23, 30.16], 31.5, [7.68, ]],
    [31.37, 31.2, [8.72]],
    [32.18, 31.4, [9.36,]],
    [33.11, 31.4, [9.92]],
    [34.15, 31, [10.48, ]],
    [[35.11,35.21], 31, [11.12]],
    [36.13, 31, [11.68, 11.76]],
    [40.10, 30.6, [13.52]],
    [45.37, 30.6, [15.52, 15.6, 15.6]],
    [50.51, 30.2, [17]],
    [55.25, 30.2, [18, 18.2]],
    [60.61, 30, [18.8, ]],
    [70.72, 29.8, [20.2]],
    [91.51, 29.2, [21.2, ]],
    [102.04, 29.2, [21.4]],
    [111.91, 29.2, [22.4, 21.8, 21.8]],
    [122.91, 29.2, [22.4, ]],
    [132.7, 29.2, 22.4],
    [142.21, 29.2, 22.6],
    [[155.09, 155.28], 29.2, [22.8, 23]],
    [166.22, 29.4, 23.2],
    #[[176.55, 176.8], [29.4, 29.6],
    [187.41, 30, [23.8, ]],
    [[197.73, 198.41, 198.73], 30.2, [24.2, 23.8, 24.2, 24.4, 24.4, 24.4]],
    [[209.73, 209.91], 30.8, [24.6, 24.4, ]],
    [[221.63, 221.43], [31.2, 31],[24.8]],
    [[230.63, 230.2], [31.2, 31.6], [25, 24.8, 25.2, 24.8]],
    [[232.99, 232.77, 233.21], 31.6, [25.4, 25.2, 25.2, ]]
]

# %%
f_U_water = []
for f, U_generator, vU_rezistor in izmerenija_water:
    f_U_water += [(np.mean(f), np.mean(vU_rezistor)/np.mean(U_generator))]

# %%
p =  list_plot(f_U_water, color="blue", legend_label='Конденсатор з водою')
p += list_plot(f_U_air,   color="green", legend_label='Конденсатор з повітрям')
p.show(axes_labels=['$f, kHz$','$U_R/U_{генератор}$'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
omega = var("omega")

# %%
X_L = L * omega
X_C = 1/(omega * C)

# %%
U_R = R/(R + X_L + X_C)

# %%
plot(U_R, omega, 0, 5000000)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(U_C, omega, 0, 5000000)
# Out:
# Graphics object consisting of 1 graphics primitive
