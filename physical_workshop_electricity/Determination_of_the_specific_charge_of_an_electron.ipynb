# %% [markdown]
# Визначення питомого заряду електрону.

# %%
R = 2.7 #Omh
L = 34.6 # mGn
l = 15 # cm
#l = 18 # cm

# %%
B_h = [
    #[0.8, 5],
    [1.6, 5],
    [7.76, 50-25],
    [7.84, 50-25],
    [7.74, 46-20],
    [18.26, 55.5-20],
    [26.54, 60-20],
    [26.41, 60-20],
    [38.68, 82-16],
    [35.62, 58-17],
]

# %%
B_R = []
one_per_B_R = [(0,0)]
for B, h in B_h:
    print(B, h)
    h_cm = h / 10
    R = (l^2 + h_cm^2) / (2*h_cm)
    B_R += [(B, R)]
    one_per_B_R += [(1/B, R)]
# Out:
# 1.60000000000000 5
# 7.76000000000000 25
# 7.84000000000000 25
# 7.74000000000000 26
# 18.2600000000000 35.5000000000000
# 26.5400000000000 40
# 26.4100000000000 40
# 38.6800000000000 66
# 35.6200000000000 41

# %%
p = list_plot(B_h)
p.show(axes_labels=['$B$','$h, mm$'])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = list_plot(B_R)
p.show(axes_labels=['$B$','$R, cm$'])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
p = list_plot(one_per_B_R)
p.show(axes_labels=['$1/B$','$R, cm$'])
# Out:
# Graphics object consisting of 1 graphics primitive
