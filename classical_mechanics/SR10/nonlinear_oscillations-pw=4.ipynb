# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from IPython.display import display, Math, Latex

def disp(ex):
    display(Math(latex(ex)))

def displ(tex):
    display(Math(tex))

# %%
# Объявление переменных и функций

t = var("t")

X = var("x")
x = function("x")(t)

x1 = function("x_1")(t)
assume(x1 < x)

x2 = function("x_2")(t)
assume(x2 < x)

omega_0 = var("omega_0")
assume(omega_0, "real")
assume(omega_0>0)

alpha = var("alpha")
assume(alpha, "real")
assume(alpha > 0)

A, phi = var("A, phi")

assume(alpha*A^2 < 1)

# %%
# линейная часть исходного дифференциального уравнения
eq0 = x.diff(t, 2) + omega_0^2 * x == 0
disp(eq0)
# Out:
# $\displaystyle \omega_{0}^{2} x\left(t\right) + \frac{\partial^{2}}{(\partial t)^{2}}x\left(t\right) = 0$

# %%
# нелинейная добавка к дифференциальному уравнению
pw = 4 # степень нелинейности
nonlinear = alpha * x * x.diff(t)^pw
disp(nonlinear)
# Out:
# $\displaystyle \alpha x\left(t\right) \frac{\partial}{\partial t}x\left(t\right)^{4}$

# %%
# исходное нелинейное дифференциальное уравнение
eq = x.diff(t, 2) + omega_0^2 * x + nonlinear == 0
disp(eq)
# Out:
# $\displaystyle \alpha x\left(t\right) \frac{\partial}{\partial t}x\left(t\right)^{4} + \omega_{0}^{2} x\left(t\right) + \frac{\partial^{2}}{(\partial t)^{2}}x\left(t\right) = 0$

# %%
# пытаемся решить его в лоб
sol = desolve(eq, x, ivar=t)
#disp(sol)

# %%
disp(sol[0].substitute_function(x == X))
# Out:
# $\displaystyle -\int \frac{1}{\sqrt{-\frac{\omega_{0} \tan\left({\left(\omega_{0} x^{2} + 2 \, K_{1} \omega_{0}\right)} \sqrt{\alpha}\right)}{\sqrt{\alpha}}}}\,{d x} = K_{2} + t$

# %%
disp(sol[1].substitute_function(x == X))
# Out:
# $\displaystyle \int \frac{1}{\sqrt{-\frac{\omega_{0} \tan\left({\left(\omega_{0} x^{2} + 2 \, K_{1} \omega_{0}\right)} \sqrt{\alpha}\right)}{\sqrt{\alpha}}}}\,{d x} = K_{2} + t$

# %%
# нулевое приближение решения
# это по сути решение линейной части исходного дифференциального уравнения
x_0 = desolve(eq0, x, ivar=t)
disp(x_0)
# Out:
# $\displaystyle K_{2} \cos\left(\omega_{0} t\right) + K_{1} \sin\left(\omega_{0} t\right)$

# %%
# нулевое приближение удобнее выбрать
# в виде косинуса от omega_0*t
# с неким сдвигом фаз phi
x0 = A * cos(omega_0*t + phi)
disp(x0)
# Out:
# $\displaystyle A \cos\left(\omega_{0} t + \phi\right)$

# %% [raw]
# # нулевое приближение удобнее выбрать
# # в виде косинуса от omega_0*t
# # с неким сдвигом фаз phi
# x0 = A * cos((omega_0+omega_1)*t + phi)
# disp(x0)

# %%
# метод последовательных приближений
# вводим добавку x1 к нулевому приближению решения,
# и подставляем это решение
# с добавкой лишь к линейной части дифференциального уравнения
# но в нелинейной части пока что пренебегаем добавкой x1
# предположив малость величины добавки x1 по сравнению с x0
eq1 = eq0.substitute_function(x == x0 + x1).lhs() \
     + nonlinear.substitute_function(x == x0) \
     == 0
disp(eq1)
# Out:
# $\displaystyle A^{5} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \sin\left(\omega_{0} t + \phi\right)^{4} - A \omega_{0}^{2} \cos\left(\omega_{0} t + \phi\right) + {\left(A \cos\left(\omega_{0} t + \phi\right) + x_{1}\left(t\right)\right)} \omega_{0}^{2} + \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) = 0$

# %%
# преобразовываем упрощая полученное новое дифференциальное уравнение
eq1 = eq1.expand()
disp(eq1)
# Out:
# $\displaystyle A^{5} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \sin\left(\omega_{0} t + \phi\right)^{4} + \omega_{0}^{2} x_{1}\left(t\right) + \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) = 0$

# %%
# понижаем в этом дифференциальном уравнении
# степень тригонометрических выражений
# за счёт увеличения кратности
# тригонометрических аргументов
eq1 = eq1.trig_reduce()
disp(eq1)
# Out:
# $\displaystyle \frac{1}{16} \, A^{5} \alpha \omega_{0}^{4} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) - \frac{3}{16} \, A^{5} \alpha \omega_{0}^{4} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) + \frac{1}{8} \, A^{5} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) + \omega_{0}^{2} x_{1}\left(t\right) + \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) = 0$

# %%
# решаем это дифференциальное уравнение относительно x1
sol1 = desolve(eq1, x1, ivar=t)
disp(sol1)
# Out:
# $\displaystyle -\frac{1}{16} \, A^{5} \alpha \omega_{0}^{3} t \sin\left(\omega_{0} t + \phi\right) + \frac{1}{384} \, A^{5} \alpha \omega_{0}^{2} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) - \frac{3}{128} \, A^{5} \alpha \omega_{0}^{2} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) - \frac{1}{32} \, A^{5} \alpha \omega_{0}^{2} \cos\left(\omega_{0} t + \phi\right) + K_{2} \cos\left(\omega_{0} t\right) + K_{1} \sin\left(\omega_{0} t\right)$

# %%
# подставляя полученное решение
# в дифференциальное уравнение
# проверяем правильность решения
test_sol1 = eq1.substitute_function(x1 == sol1).expand().trig_reduce()
test_sol1
# Out:
# 0 == 0

# %%
# отнимаем от полученного решения
# два правых слагаемых
# потому что они повторяют решение
# нулевого приближения x0
sol_1_ = sum(sol1.operands()[:-2])
disp(sol_1_)
# Out:
# $\displaystyle -\frac{1}{16} \, A^{5} \alpha \omega_{0}^{3} t \sin\left(\omega_{0} t + \phi\right) + \frac{1}{384} \, A^{5} \alpha \omega_{0}^{2} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) - \frac{3}{128} \, A^{5} \alpha \omega_{0}^{2} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) - \frac{1}{32} \, A^{5} \alpha \omega_{0}^{2} \cos\left(\omega_{0} t + \phi\right)$

# %%
# подставляя полученное решение
# первого приближения
# в дифференциальное уравнение
# проверяем правильность решения
test_eq1 = eq1.substitute_function(x1 == sol_1_).expand()
test_eq1
# Out:
# 0 == 0

# %%
# решение суммирующее нулевое и первое приближения
sol_1 = sol_1_ + x0
disp(sol_1)
# Out:
# $\displaystyle -\frac{1}{16} \, A^{5} \alpha \omega_{0}^{3} t \sin\left(\omega_{0} t + \phi\right) + \frac{1}{384} \, A^{5} \alpha \omega_{0}^{2} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) - \frac{3}{128} \, A^{5} \alpha \omega_{0}^{2} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) - \frac{1}{32} \, A^{5} \alpha \omega_{0}^{2} \cos\left(\omega_{0} t + \phi\right) + A \cos\left(\omega_{0} t + \phi\right)$

# %%
# подставляя полученное решение
# нулевого и первого приближения в сумме
# в дифференциальное уравнение
# проверяем правильность решения
test_eq1 = eq1.substitute_function(x1 == sol_1).expand()
test_eq1
# Out:
# 0 == 0

# %%
values = [
    phi == 0,
    omega_0 == 1, alpha == 0.1,
    A == 1,
]
values
# Out:
# [phi == 0, omega_0 == 1, alpha == 0.100000000000000, A == 1]

# %%
# анализируя графики нулевого и первого приближения
# приходим к выводу, что нужно убрать из решение
# резонансное слагаемое явно зависящее от времени
plot([x0.subs(values), (sol_1_).subs(values)], (t, 0, 100))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# а чтобы убрать из решения
# резонансное слагаемое явно
# нужно в дифференциальном уравнении 
disp(eq1)
# Out:
# $\displaystyle \frac{1}{16} \, A^{5} \alpha \omega_{0}^{4} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) - \frac{3}{16} \, A^{5} \alpha \omega_{0}^{4} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) + \frac{1}{8} \, A^{5} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) + \omega_{0}^{2} x_{1}\left(t\right) + \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) = 0$

# %%
# сделать обратную замену слагаемого
# имеющего ту же частоту, что и
# частота нулевого приближения

eq1_x1_lhs = 0
subs_from = cos(omega_0*t + phi)
subs_to = x1/A

for m in eq1.lhs().operands():
    if m.has(subs_from):
        m = m / subs_from * subs_to
        
    eq1_x1_lhs += m

eq1_x1 = eq1_x1_lhs == 0
disp(eq1_x1)
# Out:
# $\displaystyle \frac{1}{16} \, A^{5} \alpha \omega_{0}^{4} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) - \frac{3}{16} \, A^{5} \alpha \omega_{0}^{4} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) + \frac{1}{8} \, A^{4} \alpha \omega_{0}^{4} x_{1}\left(t\right) + \omega_{0}^{2} x_{1}\left(t\right) + \frac{\partial^{2}}{(\partial t)^{2}}x_{1}\left(t\right) = 0$

# %%
# решая дифференциальное уравнение после обратной замены
# получаем решение со смещённой частотой
sol1_x1 = desolve(eq1_x1, x1, ivar=t)
disp(sol1_x1.expand())
# Out:
# $\displaystyle -\frac{A^{9} \alpha^{2} \omega_{0}^{4} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right)}{2 \, {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}} + \frac{3 \, A^{9} \alpha^{2} \omega_{0}^{4} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right)}{2 \, {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}} + \frac{32 \, A^{5} \alpha \omega_{0}^{2} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right)}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288} - \frac{288 \, A^{5} \alpha \omega_{0}^{2} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right)}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288} + K_{2} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) + K_{1} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$

# %%
plot([x0.subs(values), (sol1_x1).subs([values, var("_K1") == 1, var("_K2") == 1])], (t, 0, 100))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
# метод последовательных приближений
# ищем второе приближение x2
# в нелинейной части пренебегаем добавкой x2
# ввиду его малости по сравнению с x0 + x1
eq2 = eq0.substitute_function(x == x0 + sol1_x1 + x2).lhs() \
     + nonlinear.substitute_function(x == x0 + sol1_x1) \
     == 0
#disp(eq2)

# %%
eq2 = eq2.expand()
#disp(eq2)
for operand in eq2.operands()[0].operands():
    disp(operand)
    print("")
# Out:
# $\displaystyle -\frac{625 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{32 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{1875 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{32 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{1125 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{3375 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{6075 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{18225 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{3645 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{10935 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{6561 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{32 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{19683 \, A^{45} \alpha^{11} \omega_{0}^{24} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{32 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{6250 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{26250 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{63000 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{243000 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{218700 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{801900 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{320760 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{1137240 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{170586 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{590490 \, A^{41} \alpha^{10} \omega_{0}^{22} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{625 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(\omega_{0} t + \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{625 \, A^{36} K_{2} \alpha^{9} \omega_{0}^{20} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{1125 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(\omega_{0} t + \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{4 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{1125 \, A^{36} K_{2} \alpha^{9} \omega_{0}^{20} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{4 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{6075 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(\omega_{0} t + \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{6075 \, A^{36} K_{2} \alpha^{9} \omega_{0}^{20} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{3645 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(\omega_{0} t + \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{4 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{3645 \, A^{36} K_{2} \alpha^{9} \omega_{0}^{20} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{4 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{6561 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(\omega_{0} t + \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{6561 \, A^{36} K_{2} \alpha^{9} \omega_{0}^{20} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{625 \, A^{36} K_{1} \alpha^{9} \omega_{0}^{20} \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{1125 \, A^{36} K_{1} \alpha^{9} \omega_{0}^{20} \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{4 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{6075 \, A^{36} K_{1} \alpha^{9} \omega_{0}^{20} \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{8 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{3645 \, A^{36} K_{1} \alpha^{9} \omega_{0}^{20} \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{4 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle \frac{6561 \, A^{36} K_{1} \alpha^{9} \omega_{0}^{20} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)}}$
# $\displaystyle -\frac{800000 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{4320000 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{10368000 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{51840000 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{46656000 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{214617600 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{85847040 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{369515520 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{55427328 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{226748160 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{4}}{{\left(A^{32} \alpha^{8} \omega_{0}^{16} - 1024 \, A^{28} \alpha^{7} \omega_{0}^{14} + 442368 \, A^{24} \alpha^{6} \omega_{0}^{12} - 104857600 \, A^{20} \alpha^{5} \omega_{0}^{10} + 14864613376 \, A^{16} \alpha^{4} \omega_{0}^{8} - 1288490188800 \, A^{12} \alpha^{3} \omega_{0}^{6} + 66795331387392 \, A^{8} \alpha^{2} \omega_{0}^{4} - 1899956092796928 \, A^{4} \alpha \omega_{0}^{2} + 22799473113563136\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{125 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{375 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{675 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{2025 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{1215 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2} \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{3645 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2} \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{729 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3} \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{2187 \, A^{37} \alpha^{9} \omega_{0}^{20} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3} \sin\left(\omega_{0} t + \phi\right)}{4 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{125 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3}}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{375 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3}}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{675 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{2025 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{1215 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{3645 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2}}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{729 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{2187 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{1} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3}}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{125 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{375 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{675 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{2025 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right)^{2} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{1215 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{3645 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle -\frac{729 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# $\displaystyle \frac{2187 \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{36} K_{2} \alpha^{9} \omega_{0}^{19} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(3 \, \omega_{0} t + 3 \, \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)}{16 \, {\left(A^{24} \alpha^{6} \omega_{0}^{12} - 768 \, A^{20} \alpha^{5} \omega_{0}^{10} + 233472 \, A^{16} \alpha^{4} \omega_{0}^{8} - 35651584 \, A^{12} \alpha^{3} \omega_{0}^{6} + 2868903936 \, A^{8} \alpha^{2} \omega_{0}^{4} - 115964116992 \, A^{4} \alpha \omega_{0}^{2} + 1855425871872\right)} {\left(A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288\right)}}$
# ...
# $\displaystyle \frac{2 \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{6} K_{2}^{3} \alpha^{2} \omega_{0}^{3} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle -\frac{18 \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{6} K_{2}^{3} \alpha^{2} \omega_{0}^{3} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle \frac{10 \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{5} K_{1} K_{2}^{3} \alpha^{2} \omega_{0}^{3} \sin\left(5 \, \omega_{0} t + 5 \, \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle -\frac{54 \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{5} K_{1} K_{2}^{3} \alpha^{2} \omega_{0}^{3} \sin\left(3 \, \omega_{0} t + 3 \, \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle \frac{12 \, A^{9} \alpha^{2} \omega_{0}^{6} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right)}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle -\frac{12 \, A^{9} \alpha^{2} \omega_{0}^{6} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right)}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle A K_{1}^{4} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}$
# $\displaystyle K_{1}^{4} K_{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{5}$
# $\displaystyle 6 \, A^{3} K_{1}^{2} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right)^{2}$
# $\displaystyle 6 \, A^{2} K_{1}^{2} K_{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\omega_{0} t + \phi\right)^{2}$
# $\displaystyle A^{5} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \sin\left(\omega_{0} t + \phi\right)^{4}$
# $\displaystyle A^{4} K_{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{4}$
# $\displaystyle -4 \, A K_{1}^{3} K_{2} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle K_{1}^{5} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -4 \, K_{1}^{3} K_{2}^{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -12 \, A^{3} K_{1} K_{2} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle 6 \, A^{2} K_{1}^{3} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -12 \, A^{2} K_{1} K_{2}^{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle A^{4} K_{1} \alpha \omega_{0}^{4} \sin\left(\omega_{0} t + \phi\right)^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle 6 \, A K_{1}^{2} K_{2}^{2} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle -4 \, K_{1}^{4} K_{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle 6 \, K_{1}^{2} K_{2}^{3} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle 6 \, A^{3} K_{2}^{2} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle -12 \, A^{2} K_{1}^{2} K_{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle 6 \, A^{2} K_{2}^{3} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle -4 \, A K_{1} K_{2}^{3} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle 6 \, K_{1}^{3} K_{2}^{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle -4 \, K_{1} K_{2}^{4} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle 6 \, A^{2} K_{1} K_{2}^{2} \alpha \omega_{0}^{4} \sin\left(\omega_{0} t + \phi\right)^{2} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle A K_{2}^{4} \alpha \omega_{0}^{4} \cos\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}$
# $\displaystyle -4 \, K_{1}^{2} K_{2}^{3} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}$
# $\displaystyle K_{2}^{5} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}$
# $\displaystyle K_{1} K_{2}^{4} \alpha \omega_{0}^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{5}$
# $\displaystyle -\sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{4} K_{1} \alpha \omega_{0}^{3} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{3}$
# $\displaystyle -\sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{3} K_{1} K_{2} \alpha \omega_{0}^{3} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right)^{3}$
# $\displaystyle \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{4} K_{2} \alpha \omega_{0}^{3} \cos\left(\omega_{0} t + \phi\right) \sin\left(\omega_{0} t + \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -\sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{3} K_{1}^{2} \alpha \omega_{0}^{3} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{3} K_{2}^{2} \alpha \omega_{0}^{3} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} A^{3} K_{1} K_{2} \alpha \omega_{0}^{3} \sin\left(\omega_{0} t + \phi\right)^{3} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle -\frac{1}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{2} K_{1}^{3} \alpha \omega_{0} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\omega_{0} t + \phi\right)$
# $\displaystyle -\frac{1}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1}^{3} K_{2} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4} \sin\left(\omega_{0} t + \phi\right)$
# $\displaystyle \frac{3}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{2} K_{1}^{2} K_{2} \alpha \omega_{0} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -\frac{1}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1}^{4} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle \frac{3}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1}^{2} K_{2}^{2} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3} \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -\frac{3}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{2} K_{1} K_{2}^{2} \alpha \omega_{0} \cos\left(\omega_{0} t + \phi\right) \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle \frac{3}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1}^{3} K_{2} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle -\frac{3}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1} K_{2}^{3} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2} \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{2}$
# $\displaystyle \frac{1}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A^{2} K_{2}^{3} \alpha \omega_{0} \cos\left(\omega_{0} t + \phi\right) \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle -\frac{3}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1}^{2} K_{2}^{2} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle \frac{1}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{2}^{4} \alpha \omega_{0} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right) \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{3}$
# $\displaystyle \frac{1}{16} \, {\left(2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}\right)}^{\frac{3}{2}} A K_{1} K_{2}^{3} \alpha \omega_{0} \sin\left(\omega_{0} t + \phi\right) \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)^{4}$
# $\displaystyle -\frac{1}{8} \, A^{4} K_{2} \alpha \omega_{0}^{4} \cos\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -\frac{1}{8} \, A^{4} K_{1} \alpha \omega_{0}^{4} \sin\left(\frac{1}{4} \, \sqrt{2 \, A^{4} \alpha \omega_{0}^{4} + 16 \, \omega_{0}^{2}} t\right)$
# $\displaystyle -\frac{768 \, A^{5} \alpha \omega_{0}^{4} \cos\left(5 \, \omega_{0} t + 5 \, \phi\right)}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle \frac{2304 \, A^{5} \alpha \omega_{0}^{4} \cos\left(3 \, \omega_{0} t + 3 \, \phi\right)}{A^{8} \alpha^{2} \omega_{0}^{4} - 256 \, A^{4} \alpha \omega_{0}^{2} + 12288}$
# $\displaystyle \omega_{0}^{2} x_{2}\left(t\right)$
# $\displaystyle \frac{\partial^{2}}{(\partial t)^{2}}x_{2}\left(t\right)$

# %%
eq2 = eq2.trig_reduce().expand()
#disp(eq2)
for operand in eq2.operands()[0].operands():
    disp(operand)
    print("")

# %%
sol2 = desolve(eq2, x2, ivar=t)
#disp(sol2)
sol2

# %% [markdown]
# ####
