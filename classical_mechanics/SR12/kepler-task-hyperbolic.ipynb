# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $E = \frac{m \dot{r}^2}{2} + \frac{m r^2 \dot{\varphi}^2}{2} + U(r) = 0$

# %% [markdown]
# Обобщённый импульс по $\varphi$ он же момент количества движения
#
# $P_{\varphi} = M = m r^2 \dot{\varphi}$
#
# откуда
#
# $\dot{\varphi} =\frac{M}{ m r^2} $

# %% [markdown]
# $U_{eff}(r) = \frac{M^2}{2 m r^2} + U(r)$

# %% [markdown]
# $E = \frac{m \dot{r}^2}{2} + \frac{M^2}{2 m r^2} + U(r) = 0$

# %%
from IPython.display import display, Math, Latex

def disp(ex):
    display(Math(latex(ex)))

def displ(tex):
    display(Math(tex))

# %%
t = var("t")
R = var("r")
assume(R, "real")
assume(R>0)

r = function("r")(t)
M = var("M")
assume(M, "real")

E = var("E")

m = var("m")
assume(m, "real")
assume(m>0)

phi = var("phi")
assume(phi, "real")

U = -1/r

u_eff = function("U_eff")(R)
disp(u_eff)

U_eff = M^2/(2*m*r^2) + U
disp(U_eff)
# Out:
# $\displaystyle U_{{\rm eff}}\left(r\right)$
# $\displaystyle \frac{M^{2}}{2 \, m r\left(t\right)^{2}} - \frac{1}{r\left(t\right)}$

# %%
values = [
    E == +0.01,
    M == 2,
    m == 1
]

# %%
plot(U.subs(r == R), R, 0, 1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(U_eff.subs(r == R).subs(values), R, 1, 50)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq_E = E == m * r.diff(t)^2/2 + U_eff
disp(eq_E)
# Out:
# $\displaystyle E = \frac{1}{2} \, m \frac{\partial}{\partial t}r\left(t\right)^{2} + \frac{M^{2}}{2 \, m r\left(t\right)^{2}} - \frac{1}{r\left(t\right)}$

# %%
eq_Eu = E == m * r.diff(t)^2/2 + u_eff
disp(eq_Eu)
# Out:
# $\displaystyle E = \frac{1}{2} \, m \frac{\partial}{\partial t}r\left(t\right)^{2} + U_{{\rm eff}}\left(r\right)$

# %%
sol_ru_diff_t = solve(eq_Eu, r.diff(t))
disp(sol_ru_diff_t)
# Out:
# $\displaystyle \left[\frac{\partial}{\partial t}r\left(t\right) = -\sqrt{\frac{2 \, E}{m} - \frac{2 \, U_{{\rm eff}}\left(r\right)}{m}}, \frac{\partial}{\partial t}r\left(t\right) = \sqrt{\frac{2 \, E}{m} - \frac{2 \, U_{{\rm eff}}\left(r\right)}{m}}\right]$

# %%
sol_r_diff_t = solve(eq_E, r.diff(t))
disp(sol_r_diff_t)
# Out:
# $\displaystyle \left[\frac{\partial}{\partial t}r\left(t\right) = -\frac{\sqrt{2 \, E m r\left(t\right)^{2} - M^{2} + 2 \, m r\left(t\right)}}{m r\left(t\right)}, \frac{\partial}{\partial t}r\left(t\right) = \frac{\sqrt{2 \, E m r\left(t\right)^{2} - M^{2} + 2 \, m r\left(t\right)}}{m r\left(t\right)}\right]$

# %%
dru_dt = sol_ru_diff_t[1].rhs()
displ("\\frac{dr}{dt} =" + latex(dru_dt))
# Out:
# $\displaystyle \frac{dr}{dt} = \sqrt{\frac{2 \, E}{m} - \frac{2 \, U_{{\rm eff}}\left(r\right)}{m}}$

# %% [markdown]
# условие $E > U_{eff}(r)$ является необходимым для получения действительных решений задачи поиска максимального и минимального радиуса

# %%
sol_neq_real = solve(E - U_eff.subs(r == R) > 0, R)
disp(sol_neq_real)
# Out:
# $\displaystyle \left[\left[0 < m, 2 \, E m r^{2} - M^{2} + 2 \, m r > 0\right], \left[m < 0, -2 \, E m r^{2} + M^{2} - 2 \, m r > 0\right]\right]$

# %%
disp(sol_neq_real[0][1].subs(values))
# Out:
# $\displaystyle 0.0200000000000000 \, r^{2} + 2 \, r - 4 > 0$

# %%
plot(sol_neq_real[0][1].lhs().subs(values), R, 1, 19)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
sol_real = solve(E - U_eff.subs(r == R) == 0, R)
disp(sol_real)
# Out:
# $\displaystyle \left[r = -\frac{m + \sqrt{2 \, E M^{2} m + m^{2}}}{2 \, E m}, r = -\frac{m - \sqrt{2 \, E M^{2} m + m^{2}}}{2 \, E m}\right]$

# %%
disp(sol_real[0].subs(values))
sol_real[0].rhs().subs(values).n()
# Out:
# $\displaystyle r = \left(-101.961524227066\right)$
# -101.961524227066

# %%
disp(sol_real[1].subs(values))
sol_real[1].rhs().subs(values).n()
# Out:
# $\displaystyle r = 1.96152422706632$
# 1.96152422706632

# %%
dr_dt = sol_r_diff_t[1].rhs()
displ("\\frac{dr}{dt} =" + latex(dr_dt))
# Out:
# $\displaystyle \frac{dr}{dt} = \frac{\sqrt{2 \, E m r\left(t\right)^{2} - M^{2} + 2 \, m r\left(t\right)}}{m r\left(t\right)}$

# %% [markdown]
# точки перигея и эпогея определяются
#
# $\frac{dr}{d{t}} = 0$

# %%
sol_r_min_max = solve(dr_dt == 0, r)
disp(sol_r_min_max)
# Out:
# $\displaystyle \left[r\left(t\right) = -\frac{m + \sqrt{2 \, E M^{2} m + m^{2}}}{2 \, E m}, r\left(t\right) = -\frac{m - \sqrt{2 \, E M^{2} m + m^{2}}}{2 \, E m}\right]$

# %%
disp(sol_r_min_max[0].subs(values))
sol_r_min_max[0].rhs().subs(values).n()
# Out:
# $\displaystyle r\left(t\right) = \left(-101.961524227066\right)$
# -101.961524227066

# %%
disp(sol_r_min_max[1].subs(values))
sol_r_min_max[1].rhs().subs(values).n()
# Out:
# $\displaystyle r\left(t\right) = 1.96152422706632$
# 1.96152422706632

# %%
(dt_dr) = (1/dr_dt)
displ("dt = " + latex(dt_dr) + "\\, dr")
# Out:
# $\displaystyle dt = \frac{m r\left(t\right)}{\sqrt{2 \, E m r\left(t\right)^{2} - M^{2} + 2 \, m r\left(t\right)}} \, dr$

# %% [markdown]
# поскольку
#
# $\dot{\varphi} =\frac{M}{ m r^2} $
#
#
# $d{\varphi} =\frac{M}{ m r^2}\,dt$

# %%
dphi_dr = M/(m*r^2) * dt_dr
displ("d{\\varphi} = " +latex(dphi_dr) + "\\, dr")
# Out:
# $\displaystyle d{\varphi} = \frac{M}{\sqrt{2 \, E m r\left(t\right)^{2} - M^{2} + 2 \, m r\left(t\right)} r\left(t\right)} \, dr$

# %%
dphi_dR = dphi_dr.subs(r == R)
displ("d{\\varphi} = " +latex(dphi_dR) + "\\, dr")
# Out:
# $\displaystyle d{\varphi} = \frac{M}{\sqrt{2 \, E m r^{2} - M^{2} + 2 \, m r} r} \, dr$

# %% [markdown]
# траектория
#
# $\varphi (r) = \int d{\varphi}$

# %%
(m+2*E*M^2>0).subs(values)
# Out:
# 1.08000000000000 > 0

# %%
assume(M>0)
assume(m+2*E*M^2>0) # for Kepler U = -1/r

phi_R = dphi_dR.integrate(R)
displ("\\varphi = " +latex(phi_R) + "")
# Out:
# $\displaystyle \varphi = -\arcsin\left(-\frac{m}{\sqrt{2 \, E M^{2} m + m^{2}}} + \frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} r}\right)$

# %%
phi_diff_R = phi_R.diff(R)
disp(phi_diff_R)
# Out:
# $\displaystyle \frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} \sqrt{-{\left(\frac{m}{\sqrt{2 \, E M^{2} m + m^{2}}} - \frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} r}\right)}^{2} + 1} r^{2}}$

# %%
disp((phi_diff_R - dphi_dR).expand())
# Out:
# $\displaystyle -\frac{M}{\sqrt{2 \, E m r^{2} - M^{2} + 2 \, m r} r} + \frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} \sqrt{-\frac{m^{2}}{2 \, E M^{2} m + m^{2}} - \frac{M^{4}}{{\left(2 \, E M^{2} m + m^{2}\right)} r^{2}} + \frac{2 \, M^{2} m}{{\left(2 \, E M^{2} m + m^{2}\right)} r} + 1} r^{2}}$

# %%
plot((phi_diff_R - dphi_dR).expand().subs(values), R)
# Out:
# verbose 0 (3885: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 100 points.
# verbose 0 (3885: plot.py, generate_plot_points) Last error message: 'Unable to compute f(-0.0010532329586645317)'
# Graphics object consisting of 1 graphics primitive

# %%
sin_minus_phi = phi_R.operands()[0].operands()[0]
disp(sin_minus_phi)
# Out:
# $\displaystyle -\frac{m}{\sqrt{2 \, E M^{2} m + m^{2}}} + \frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} r}$

# %%
s = var("s")
sol_R_sin_minus_phi = solve(sin_minus_phi == s, R)
disp(sol_R_sin_minus_phi)
# Out:
# $\displaystyle \left[r = \frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} s + m}\right]$

# %%
sol_R_phi = sol_R_sin_minus_phi[0].subs(s == -sin(phi))
disp(sol_R_phi)
# Out:
# $\displaystyle r = -\frac{M^{2}}{\sqrt{2 \, E M^{2} m + m^{2}} \sin\left(\phi\right) - m}$

# %%
disp(sol_R_phi.rhs().subs(values))
# Out:
# $\displaystyle -\frac{4}{1.03923048454133 \, \sin\left(\phi\right) - 1}$

# %%
disp(sol_R_phi.rhs().numerator())
# Out:
# $\displaystyle -M^{2}$

# %%
sol_R_phi_den = sol_R_phi.rhs().denominator()
disp(sol_R_phi_den)
# Out:
# $\displaystyle \sqrt{2 \, E M^{2} m + m^{2}} \sin\left(\phi\right) - m$

# %%
sin_phi_assimptotics = solve(sol_R_phi_den == 0, sin(phi))
disp(sin_phi_assimptotics)
# Out:
# $\displaystyle \left[\sin\left(\phi\right) = \frac{m}{\sqrt{2 \, E M^{2} m + m^{2}}}\right]$

# %%
phi_assimptotics = solve(sol_R_phi_den == 0, phi)
disp(sin_phi_assimptotics)
# Out:
# $\displaystyle \left[\sin\left(\phi\right) = \frac{m}{\sqrt{2 \, E M^{2} m + m^{2}}}\right]$

# %%
disp(sin_phi_assimptotics[0].rhs().subs(values))
# Out:
# $\displaystyle 0.962250448649376$

# %%
phi_assimptotic = arcsin(sin_phi_assimptotics[0].rhs())
disp(phi_assimptotic)
phi_assimpt = phi_assimptotic.subs(values)
phi_assimpt
# Out:
# $\displaystyle \arcsin\left(\frac{m}{\sqrt{2 \, E M^{2} m + m^{2}}}\right)$
# 1.29515352757863

# %%
polar_plot(sol_R_phi.rhs().subs(values), (phi, -pi-phi_assimpt+0.15, phi_assimpt-0.15), color=hue(0.5), thickness=4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_R_phi.rhs().subs(values), (phi, -pi-phi_assimpt+0.15, phi_assimpt-0.15), color=hue(0.5), thickness=4)
# Out:
# Graphics object consisting of 1 graphics primitive
